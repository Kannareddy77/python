# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from scipy.stats import norm

# %%
import statistics as stats

# %%
norm.pdf(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 norm.pdf(data)
#
# NameError: name 'data' is not defined

# %%
data=np.linspace(0,10,10000)

# %%
data1=np.random.randn(10000)

# %%
data1
# Out:
# array([-0.48617685,  0.31442509, -1.20964992, ...,  0.94783514,
#        -0.52910803,  0.17260058], shape=(10000,))

# %%
np.mean(data1)
# Out:
# np.float64(0.008121164080848706)

# %%
np.median(data1)
# Out:
# np.float64(0.0072407735651728354)

# %%
stats.mode(data1)
# Out:
# np.float64(-0.4861768463368836)

# %%
np.std(data1)
# Out:
# np.float64(0.9947508968981508)

# %%
data
# Out:
# array([0.00000000e+00, 1.00010001e-03, 2.00020002e-03, ...,
#        9.99799980e+00, 9.99899990e+00, 1.00000000e+01], shape=(10000,))

# %%
np.mean(data)
# Out:
# np.float64(5.0)

# %%
np.median(data)
# Out:
# np.float64(5.0)

# %%
stats.mode(data)
# Out:
# np.float64(0.0)

# %%
np.std(data)
# Out:
# np.float64(2.887040035517924)

# %%
norm.pdf(data)
# Out:
# array([3.98942280e-01, 3.98942081e-01, 3.98941482e-01, ...,
#        7.85003983e-23, 7.77193451e-23, 7.69459863e-23], shape=(10000,))

# %%
plt.figure(figsize=(10,10))

# %%
plt.plot(data,norm.data1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 plt.plot(data,norm.data1)
#
# AttributeError: 'norm_gen' object has no attribute 'data1'

# %%
plt.scatter(data,norm.pdf(data1))

# %%
data2=np.linspace(0,10,100)

# %%
data2
# Out:
# array([0.00000000e+00, 1.00010001e-03, 2.00020002e-03, ...,
#        9.99799980e+00, 9.99899990e+00, 1.00000000e+01], shape=(10000,))

# %%
data2.mean()
# Out:
# np.float64(5.0)

# %%
np.median(data2)
# Out:
# np.float64(5.0)

# %%
stats.mode(data2)
# Out:
# np.float64(0.0)

# %%
np.std(data2)
# Out:
# np.float64(2.887040035517924)

# %%
norm.pdf(data2)
# Out:
# array([3.98942280e-01, 3.98942081e-01, 3.98941482e-01, ...,
#        7.85003983e-23, 7.77193451e-23, 7.69459863e-23], shape=(10000,))

# %%
plt.figure(figsize=(10,10))

# %%
plt.plot(data2,norm.pdf(data2))

# %%
plt.scatter(data2,norm.pdf(data2))

# %%
data4=np.random.randn(1000)

# %%
data4
# Out:
# array([ 1.52707920e-01, -1.70177032e-02, -1.85326379e+00, -8.43454523e-01,
#         8.60684059e-01, -1.11700765e+00,  6.57936862e-01, -7.18606918e-01,
#         5.82488624e-01,  1.79044682e+00, -1.56704657e+00,  1.85775224e-01,
#         3.58497819e-01, -5.13177893e-01, -1.85841182e+00,  9.26433533e-01,
#         1.99133029e-01,  1.97063821e+00, -2.47089004e+00,  1.92210021e+00,
#         1.10133315e+00, -6.77957551e-01, -6.58861618e-01,  7.27097106e-01,
#        -1.13487184e+00, -1.17832398e+00, -9.43036967e-01,  9.81309910e-01,
#        -1.92977252e+00,  1.22730725e+00,  6.68072233e-01,  1.50518615e-01,
#         1.58571990e+00, -9.62343939e-01, -1.13423931e+00,  4.09183358e-02,
#        -6.32781454e-01,  4.90575098e-01, -3.04001481e-01, -7.20613532e-01,
#        -1.10210514e+00,  1.36733813e+00,  1.79170840e+00,  8.46255178e-01,
#        -2.05416950e-01,  7.77194013e-01, -9.74078921e-01, -4.72428478e-01,
# ...

# %%
np.mean(data4)
# Out:
# np.float64(-0.01712233706431762)

# %%
np.median(data4)
# Out:
# np.float64(-0.0017569538997604767)

# %%
stats.mode(data4)
# Out:
# np.float64(0.15270792019830606)

# %%
np.std(data4)
# Out:
# np.float64(0.9819965458042806)

# %%
norm.pdf(data4)
# Out:
# array([0.39431768, 0.39888452, 0.07163068, 0.27952982, 0.27545609,
#        0.21378347, 0.32130033, 0.3081599 , 0.33669257, 0.08031584,
#        0.11686265, 0.3921171 , 0.37411244, 0.34972285, 0.07094958,
#        0.25973898, 0.39111036, 0.05723178, 0.0188435 , 0.06290226,
#        0.21753274, 0.31703226, 0.32110476, 0.30627447, 0.20952639,
#        0.19925652, 0.255739  , 0.24649265, 0.06197963, 0.18785591,
#        0.31914849, 0.39444859, 0.11347278, 0.25107804, 0.20967681,
#        0.39860844, 0.32655898, 0.35371262, 0.38092721, 0.30771524,
#        0.21734781, 0.15664936, 0.08013456, 0.27886919, 0.39061354,
#        0.29494871, 0.24824145, 0.35681677, 0.17063216, 0.27623105,
#        0.39563365, 0.34992456, 0.37617318, 0.36460696, 0.39683318,
#        0.23007558, 0.32460839, 0.01779349, 0.17102335, 0.02565886,
#        0.31007048, 0.31901011, 0.39841147, 0.30881325, 0.39565508,
#        0.32070521, 0.39687069, 0.31430243, 0.39342929, 0.3855473 ,
# ...

# %%
plt.scatter(data4,norm.pdf(data4))

# %%
plt.plot(data4,norm.pdf(data4))
